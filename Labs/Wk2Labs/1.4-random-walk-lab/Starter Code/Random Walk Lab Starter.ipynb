# %% [markdown]
# ***Exercise Random Wlak***
#
# 1. Write a function RandomWalk that takes two integers L and R and which returns an array with R simulated random walks starting at position 0 of length L.
# 2. Plot the simulated RandomWalk (Tip: lets say result is the array that was returned by RandomWalk. You will need to transpose the array using array.T when plotting the walks)
# 3. Plot the histogram of the number of final positions. (Extra: What distribution does that histogram represent? Can you guess the variance and the mean?)
# 4. Wite a function called DoubleSlit which takes an array of RandomWalks and 5 integers P, L1, U!, L2, and U2. The function DoubleSplit removes all path from RandomWalk that do not pass through two slits defined by (L1, U1) and (L2, U2) at position P.
# 5. Plot the simulated DoubleSplit for various parameters.
# 6. Plot the histogram of the number of final positions. What can you say about the form of the distribution?

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

def RandomWalk(R,L):
    Walk = np.random.uniform(low = -1, high = 1, size =(R,L))
    Walk[:,0]=0
    return Walk.cumsum(axis = 1)

#use raw input to enter varaiables   
L = int(raw_input("Enter Walk Length): "))
R = int(raw_input("Enter Walks): "))

WalkArray = RandomWalk(R,L)
plt.plot(WalkArray.T)
plt.show()
    
LastStep = RandomWalk(R,L)[:,L]
RandomWalk(R,L)
# Out:
# Enter Walk Length): 500
# Enter Walks): 1000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-27f250751b64> in <module>()
#      16 plt.show()
#      17
# ---> 18 LastStep = RandomWalk(R,L)[:,L]
#      19 RandomWalk(R,L)
#      20
#
# IndexError: index 500 is out of bounds for axis 1 with size 500

# %%
def DoubleSlit(my_array,P,L1,U1,L2,U2):
    return Walk_Array[((WalkArray[:,P]>L1)& (WalkArray[:,P]<U1))] | \
            

Walk = Walk[((Walk[:, 700] > -60) & (Walk[:, 700] < -50))| (Walk[:, 700] > 50) & (Walk[:, 700] < 60)]
fig = plt.figure()
ax = plt.subplot(1,1,1)
ax.plot(Walk.T, color = 'blue')
ax.set_xlim([0,1000])
ax.set_ylim([-100,100])
fig2 = plt.figure()
ax2 = plt.subplot(1,1,1)
ax2.hist(Walk[:,-1].T, bins = 20)
# Out:
# array([[-0.65247549,  0.79069644, -0.99858287,  0.47043946, -0.44812424,
#         -0.11397636,  0.61653785],
#        [ 0.11457255, -0.83521165, -0.73715379,  0.81971787,  0.84338208,
#         -0.9225189 , -0.10626835],
#        [ 0.61656309,  0.79223434, -0.51390647, -0.68301702, -0.19301695,
#         -0.60023624, -0.75447573],
#        [ 0.73523686,  0.13753258,  0.5182138 ,  0.97572256,  0.66810857,
#          0.89233406, -0.2076756 ],
#        [ 0.28368537, -0.20713448,  0.6706979 ,  0.73406279, -0.3555707 ,
#          0.19376717, -0.96820434]])
